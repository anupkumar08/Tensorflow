# %%
import os
import zipfile
import random
import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from shutil import copyfile

# %%
# If the URL doesn't work, visit https://www.microsoft.com/en-us/download/confirmation.aspx?id=54765
# And right click on the 'Download Manually' link to get a new URL to the dataset

# Note: This is a very large dataset and will take time to download

# !wget --no-check-certificate \
    "https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_3367a.zip" \
    -O "/tmp/cats-and-dogs.zip"

local_zip = '/tmp/cats-and-dogs.zip'
zip_ref   = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()
# Out:
# --2020-07-26 09:55:45--  https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_3367a.zip
# Resolving download.microsoft.com (download.microsoft.com)... 23.35.76.84, 2600:1407:b800:2ad::e59, 2600:1407:b800:2a5::e59, ...
# Connecting to download.microsoft.com (download.microsoft.com)|23.35.76.84|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 824894548 (787M) [application/octet-stream]
# Saving to: ‘/tmp/cats-and-dogs.zip’
#
# /tmp/cats-and-dogs. 100%[===================>] 786.68M   151MB/s    in 5.2s
#
# 2020-07-26 09:55:50 (152 MB/s) - ‘/tmp/cats-and-dogs.zip’ saved [824894548/824894548]

# %%
os.listdir('/tmp/PetImages/')
# Out:
# ['Cat', 'Dog']

# %%
print(len(os.listdir('/tmp/PetImages/Cat/')))
print(len(os.listdir('/tmp/PetImages/Dog/')))

# Expected Output:
# 12501
# 12501
# Out:
# 12501
# 12501

# %%
try:
    os.mkdir('/tmp/cats-v-dogs')
    os.mkdir('/tmp/cats-v-dogs/training')
    os.mkdir('/tmp/cats-v-dogs/testing')
    os.mkdir('/tmp/cats-v-dogs/training/cats')
    os.mkdir('/tmp/cats-v-dogs/training/dogs')
    os.mkdir('/tmp/cats-v-dogs/testing/cats')
    os.mkdir('/tmp/cats-v-dogs/testing/dogs')
except OSError:
    pass

# %%
def split_data(SOURCE, TRAINING, TESTING, SPLIT_SIZE):
    files = []
    for filename in os.listdir(SOURCE):
        file = SOURCE + filename
        if os.path.getsize(file) > 0:
            files.append(filename)
        else:
            print(filename + " is zero length, so ignoring.")

    training_length = int(len(files) * SPLIT_SIZE)
    testing_length = int(len(files) - training_length)
    shuffled_set = random.sample(files, len(files))
    training_set = shuffled_set[0:training_length]
    testing_set = shuffled_set[-testing_length:]

    for filename in training_set:
        this_file = SOURCE + filename
        destination = TRAINING + filename
        copyfile(this_file, destination)

    for filename in testing_set:
        this_file = SOURCE + filename
        destination = TESTING + filename
        copyfile(this_file, destination)


CAT_SOURCE_DIR = "/tmp/PetImages/Cat/"
TRAINING_CATS_DIR = "/tmp/cats-v-dogs/training/cats/"
TESTING_CATS_DIR = "/tmp/cats-v-dogs/testing/cats/"
DOG_SOURCE_DIR = "/tmp/PetImages/Dog/"
TRAINING_DOGS_DIR = "/tmp/cats-v-dogs/training/dogs/"
TESTING_DOGS_DIR = "/tmp/cats-v-dogs/testing/dogs/"

split_size = .9
split_data(CAT_SOURCE_DIR, TRAINING_CATS_DIR, TESTING_CATS_DIR, split_size)
split_data(DOG_SOURCE_DIR, TRAINING_DOGS_DIR, TESTING_DOGS_DIR, split_size)

# Expected output
# 666.jpg is zero length, so ignoring
# 11702.jpg is zero length, so ignoring
# Out:
# 666.jpg is zero length, so ignoring.
# 11702.jpg is zero length, so ignoring.

# %%
print(len(os.listdir('/tmp/cats-v-dogs/training/cats/')))
print(len(os.listdir('/tmp/cats-v-dogs/training/dogs/')))
print(len(os.listdir('/tmp/cats-v-dogs/testing/cats/')))
print(len(os.listdir('/tmp/cats-v-dogs/testing/dogs/')))

# Expected output:
# 11250
# 11250
# 1250
# 1250
# Out:
# 11250
# 11250
# 1250
# 1250

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer=RMSprop(lr=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
TRAINING_DIR = "/tmp/cats-v-dogs/training/"
train_datagen = ImageDataGenerator(rescale=1.0/255.)
train_generator = train_datagen.flow_from_directory(TRAINING_DIR,
                                                    batch_size=100,
                                                    class_mode='binary',
                                                    target_size=(150, 150))

VALIDATION_DIR = "/tmp/cats-v-dogs/testing/"
validation_datagen = ImageDataGenerator(rescale=1.0/255.)
validation_generator = validation_datagen.flow_from_directory(VALIDATION_DIR,
                                                              batch_size=100,
                                                              class_mode='binary',
                                                              target_size=(150, 150))

# Expected Output:
# Found 22498 images belonging to 2 classes.
# Found 2500 images belonging to 2 classes.
# Out:
# Found 22498 images belonging to 2 classes.
# Found 2500 images belonging to 2 classes.

# %%
# Note that this may take some time.
history = model.fit(train_generator,
                              epochs=50,
                              verbose=1,
                              validation_data=validation_generator)
# Out:
# Epoch 1/50
# 114/225 [==============>...............] - ETA: 3:56 - loss: 0.8168 - accuracy: 0.5796
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32 bytes but only got 0. Skipping tag 270
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 5 bytes but only got 0. Skipping tag 271
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 272
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 282
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 283
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 20 bytes but only got 0. Skipping tag 306
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 48 bytes but only got 0. Skipping tag 532
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:788: UserWarning: Corrupt EXIF data.  Expecting to read 2 bytes but only got 0.
#   warnings.warn(str(msg))
# 225/225 [==============================] - 504s 2s/step - loss: 0.7215 - accuracy: 0.6225 - val_loss: 0.5730 - val_accuracy: 0.7140
# Epoch 2/50
# 225/225 [==============================] - 501s 2s/step - loss: 0.5274 - accuracy: 0.7339 - val_loss: 0.4697 - val_accuracy: 0.7700
# Epoch 3/50
# 225/225 [==============================] - 496s 2s/step - loss: 0.4489 - accuracy: 0.7907 - val_loss: 0.5097 - val_accuracy: 0.7684
# Epoch 4/50
# 225/225 [==============================] - 500s 2s/step - loss: 0.3877 - accuracy: 0.8241 - val_loss: 0.4243 - val_accuracy: 0.8068
# Epoch 5/50
# 225/225 [==============================] - 498s 2s/step - loss: 0.3306 - accuracy: 0.8547 - val_loss: 0.3840 - val_accuracy: 0.8348
# Epoch 6/50
# 225/225 [==============================] - 494s 2s/step - loss: 0.2670 - accuracy: 0.8863 - val_loss: 0.4387 - val_accuracy: 0.8192
# Epoch 7/50
# 225/225 [==============================] - 493s 2s/step - loss: 0.1947 - accuracy: 0.9199 - val_loss: 0.4706 - val_accuracy: 0.8108
# Epoch 8/50
# 225/225 [==============================] - 490s 2s/step - loss: 0.1303 - accuracy: 0.9503 - val_loss: 0.4968 - val_accuracy: 0.8244
# Epoch 9/50
# 225/225 [==============================] - 494s 2s/step - loss: 0.0825 - accuracy: 0.9717 - val_loss: 0.7532 - val_accuracy: 0.8176
# Epoch 10/50
# 225/225 [==============================] - 493s 2s/step - loss: 0.0728 - accuracy: 0.9766 - val_loss: 0.6727 - val_accuracy: 0.8236
# Epoch 11/50
# 225/225 [==============================] - 495s 2s/step - loss: 0.0556 - accuracy: 0.9827 - val_loss: 0.7442 - val_accuracy: 0.8164
# Epoch 12/50
# 225/225 [==============================] - 493s 2s/step - loss: 0.0418 - accuracy: 0.9880 - val_loss: 0.8241 - val_accuracy: 0.8208
# Epoch 13/50
# 225/225 [==============================] - 491s 2s/step - loss: 0.0499 - accuracy: 0.9881 - val_loss: 0.9460 - val_accuracy: 0.8296
# Epoch 14/50
# 225/225 [==============================] - 490s 2s/step - loss: 0.0369 - accuracy: 0.9892 - val_loss: 0.9595 - val_accuracy: 0.8280
# Epoch 15/50
# 225/225 [==============================] - 493s 2s/step - loss: 0.0369 - accuracy: 0.9913 - val_loss: 1.1311 - val_accuracy: 0.8236
# Epoch 16/50
# 225/225 [==============================] - 493s 2s/step - loss: 0.0446 - accuracy: 0.9909 - val_loss: 1.1461 - val_accuracy: 0.8308
# Epoch 17/50
# 225/225 [==============================] - 492s 2s/step - loss: 0.0399 - accuracy: 0.9924 - val_loss: 1.2343 - val_accuracy: 0.8348
# Epoch 18/50
# 225/225 [==============================] - 494s 2s/step - loss: 0.0347 - accuracy: 0.9916 - val_loss: 1.1872 - val_accuracy: 0.8316
# Epoch 19/50
# 225/225 [==============================] - 492s 2s/step - loss: 0.0333 - accuracy: 0.9916 - val_loss: 1.1422 - val_accuracy: 0.8252
# Epoch 20/50
# 225/225 [==============================] - 493s 2s/step - loss: 0.0406 - accuracy: 0.9903 - val_loss: 1.1014 - val_accuracy: 0.8244
# Epoch 21/50
# 225/225 [==============================] - 491s 2s/step - loss: 0.0729 - accuracy: 0.9907 - val_loss: 1.1446 - val_accuracy: 0.8292
# Epoch 22/50
# 225/225 [==============================] - 493s 2s/step - loss: 0.0304 - accuracy: 0.9934 - val_loss: 1.2431 - val_accuracy: 0.8308
# Epoch 23/50
# 225/225 [==============================] - 492s 2s/step - loss: 0.0380 - accuracy: 0.9917 - val_loss: 1.3408 - val_accuracy: 0.8316
# Epoch 24/50
# 225/225 [==============================] - 491s 2s/step - loss: 0.0396 - accuracy: 0.9918 - val_loss: 1.5191 - val_accuracy: 0.8148
# Epoch 25/50
# 225/225 [==============================] - 492s 2s/step - loss: 0.0395 - accuracy: 0.9920 - val_loss: 1.3155 - val_accuracy: 0.8336
# Epoch 26/50
# 225/225 [==============================] - 495s 2s/step - loss: 0.0257 - accuracy: 0.9934 - val_loss: 1.3721 - val_accuracy: 0.8184
# Epoch 27/50
# 225/225 [==============================] - 492s 2s/step - loss: 0.0324 - accuracy: 0.9931 - val_loss: 1.3329 - val_accuracy: 0.8288
# Epoch 28/50
# 225/225 [==============================] - 492s 2s/step - loss: 0.0488 - accuracy: 0.9909 - val_loss: 1.3455 - val_accuracy: 0.8000
# Epoch 29/50
# 225/225 [==============================] - 492s 2s/step - loss: 0.0356 - accuracy: 0.9918 - val_loss: 1.7279 - val_accuracy: 0.8320
# Epoch 30/50
# 225/225 [==============================] - 490s 2s/step - loss: 0.0561 - accuracy: 0.9899 - val_loss: 1.4272 - val_accuracy: 0.8284
# Epoch 31/50
# 225/225 [==============================] - 494s 2s/step - loss: 0.0466 - accuracy: 0.9897 - val_loss: 1.6232 - val_accuracy: 0.8284
# Epoch 32/50
# 225/225 [==============================] - 495s 2s/step - loss: 0.0376 - accuracy: 0.9908 - val_loss: 1.7921 - val_accuracy: 0.7940
# Epoch 33/50
# 225/225 [==============================] - 497s 2s/step - loss: 0.0329 - accuracy: 0.9921 - val_loss: 1.6435 - val_accuracy: 0.8184
# Epoch 34/50
# 225/225 [==============================] - 495s 2s/step - loss: 0.0391 - accuracy: 0.9931 - val_loss: 1.5179 - val_accuracy: 0.8236
# Epoch 35/50
# 225/225 [==============================] - 492s 2s/step - loss: 0.0480 - accuracy: 0.9908 - val_loss: 1.7173 - val_accuracy: 0.8292
# Epoch 36/50
# 225/225 [==============================] - 493s 2s/step - loss: 0.0394 - accuracy: 0.9924 - val_loss: 1.7106 - val_accuracy: 0.8248
# Epoch 37/50
# 225/225 [==============================] - 494s 2s/step - loss: 0.0359 - accuracy: 0.9914 - val_loss: 1.6888 - val_accuracy: 0.8256
# Epoch 38/50
# 225/225 [==============================] - 494s 2s/step - loss: 0.0586 - accuracy: 0.9888 - val_loss: 1.5041 - val_accuracy: 0.8216
# Epoch 39/50
# 225/225 [==============================] - 493s 2s/step - loss: 0.0285 - accuracy: 0.9930 - val_loss: 1.9194 - val_accuracy: 0.8012
# Epoch 40/50
# 225/225 [==============================] - 491s 2s/step - loss: 0.0689 - accuracy: 0.9893 - val_loss: 1.5718 - val_accuracy: 0.8216
# Epoch 41/50
# 225/225 [==============================] - 495s 2s/step - loss: 0.0603 - accuracy: 0.9904 - val_loss: 4.5859 - val_accuracy: 0.7084
# Epoch 42/50
# 225/225 [==============================] - 493s 2s/step - loss: 0.0895 - accuracy: 0.9892 - val_loss: 1.7999 - val_accuracy: 0.8012
# Epoch 43/50
# 225/225 [==============================] - 492s 2s/step - loss: 0.0516 - accuracy: 0.9903 - val_loss: 1.3430 - val_accuracy: 0.8200
# Epoch 44/50
# 225/225 [==============================] - 492s 2s/step - loss: 0.0294 - accuracy: 0.9935 - val_loss: 1.8070 - val_accuracy: 0.8156
# Epoch 45/50
# 225/225 [==============================] - 492s 2s/step - loss: 0.0330 - accuracy: 0.9932 - val_loss: 1.9764 - val_accuracy: 0.8236
# Epoch 46/50
# 225/225 [==============================] - 489s 2s/step - loss: 0.0568 - accuracy: 0.9891 - val_loss: 1.4854 - val_accuracy: 0.8072
# Epoch 47/50
# 225/225 [==============================] - 490s 2s/step - loss: 0.0467 - accuracy: 0.9915 - val_loss: 1.5642 - val_accuracy: 0.8244
# Epoch 48/50
# 225/225 [==============================] - 494s 2s/step - loss: 0.0282 - accuracy: 0.9928 - val_loss: 1.7246 - val_accuracy: 0.8200
# Epoch 49/50
# 225/225 [==============================] - 493s 2s/step - loss: 0.0687 - accuracy: 0.9891 - val_loss: 1.9225 - val_accuracy: 0.8268
# Epoch 50/50
# 225/225 [==============================] - 494s 2s/step - loss: 0.0603 - accuracy: 0.9906 - val_loss: 1.6161 - val_accuracy: 0.8292

# %%
# %matplotlib inline

import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r', "Training Accuracy")
plt.plot(epochs, val_acc, 'b', "Validation Accuracy")
plt.title('Training and validation accuracy')
plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r', "Training Loss")
plt.plot(epochs, val_loss, 'b', "Validation Loss")
plt.figure()


# Desired output. Charts with training and validation metrics. No crash :)

# %%
# Here's a codeblock just for fun. You should be able to upload an image here 
# and have it classified without crashing
import numpy as np
from google.colab import files
from keras.preprocessing import image

uploaded = files.upload()

for fn in uploaded.keys():
 
  # predicting images
  path = '/content/' + fn
  img = image.load_img(path, target_size=(150, 150))
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)
  print(classes[0])
  if classes[0]>0.5:
    print(fn + " is a dog")
  else:
    print(fn + " is a cat")
# Out:
#      <input type="file" id="files-d1654657-3a79-4629-9727-b3edeaa0b7f5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d1654657-3a79-4629-9727-b3edeaa0b7f5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cat3.jpg to cat3.jpg
# [1.]
# cat3.jpg is a dog
